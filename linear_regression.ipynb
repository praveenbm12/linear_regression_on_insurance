# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
insurance = pd.read_csv('/content/new_insurance_data (1).csv')

# %%
insurance
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0         715428.0          4.720921e+06                              0.0
# 1         699157.0          4.329832e+06                              0.0
# 2         702341.0          6.884861e+06                              0.0
# 3         700250.0          4.274774e+06                              0.0
# 4         711584.0          3.787294e+06                              0.0
# ...            ...                   ...                              ...
# 1333     1091267.0          1.703805e+08                              2.0
# 1334     1107872.0          2.015152e+08                              2.0
# 1335     1092005.0          2.236450e+08                              2.0
# 1336     1106821.0          2.528924e+08                              3.0
# 1337     1100328.0          2.616317e+08                              3.0
#
#       Anual_Salary     region      charges
# 0     5.578497e+07  southeast   1121.87390
# 1     1.370089e+07  southeast   1131.50660
# 2     7.352311e+07  southeast   1135.94070
# 3     7.581968e+07  southeast   1136.39940
# 4     2.301232e+07  southeast   1137.01100
# ...            ...        ...          ...
# 1333  3.101107e+09  northwest  55135.40209
# 1334  3.484216e+09  northeast  58571.07448
# 1335  3.640807e+09  northwest  60021.39897
# 1336  4.006359e+09  southeast  62592.87309
# 1337  4.117197e+09  southeast  63770.42801
#
# [1338 rows x 13 columns]

# %%
insurance.shape
# Out:
# (1338, 13)

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   object
#  12  charges                          1338 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 136.0+ KB

# %%
insurance.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
col = list(insurance.columns)
col
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %%
insurance['age'].mean()
# Out:
# 39.31000752445448

# %%
insurance['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
insurance['smoker'].mode()[0]
# Out:
# 'no'

# %%
#insurance['smoker'] = insurance['smoker'].fillna(insurance['smoker'].mode()[0])
# object ----> mode
# num -------> mean/median
for col_name in col:
  if insurance[col_name].dtypes=='object':
    insurance[col_name] = insurance[col_name].fillna(insurance[col_name].mode()[0])
  else:
    insurance[col_name] = insurance[col_name].fillna(insurance[col_name].mean())

# %%
insurance.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
insurance.head()
# Out:
#     age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0  18.0  male  23.21       0.0     no   29087.54313                17.0
# 1  18.0  male  30.14       0.0     no   39053.67437                 7.0
# 2  18.0  male  33.33       0.0     no   39023.62759                19.0
# 3  18.0  male  33.66       0.0     no   28185.39332                11.0
# 4  18.0  male  34.10       0.0     no   14697.85941                16.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      715428.0           4720920.992                              0.0
# 1      699157.0           4329831.676                              0.0
# 2      702341.0           6884860.774                              0.0
# 3      700250.0           4274773.550                              0.0
# 4      711584.0           3787293.921                              0.0
#
#    Anual_Salary     region    charges
# 0   55784970.05  southeast  1121.8739
# 1   13700885.19  southeast  1131.5066
# 2   73523107.27  southeast  1135.9407
# 3   75819679.60  southeast  1136.3994
# 4   23012320.01  southeast  1137.0110

# %%
plt.hist(insurance['age'])
plt.xlabel('age')
plt.ylabel('count')
plt.show()

# %%
sns.distplot(insurance['age'])
# Out:
# <ipython-input-118-461a13c574f2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
for col_name in col:
  if(insurance[col_name].dtypes=='int64' or insurance[col_name].dtypes=='float64'):
    sns.distplot(insurance[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()
# Out:
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])
# <ipython-input-119-142a82f24890>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance[col_name])

# %%
insurance.describe()
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.310008    30.665112     1.090773  33361.327180
# std      13.987500     6.094840     1.199606  15535.307255
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.315000     0.000000  20947.645198
# 50%      39.310008    30.400000     1.000000  33611.286065
# 75%      51.000000    34.656250     2.000000  44978.873188
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1338.000000  1.338000e+03          1.338000e+03
# mean            15.216216  9.100047e+05          1.584179e+07
# std              7.450948  9.178297e+04          2.665309e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.474898e+05          4.084941e+06
# 50%             15.000000  9.140155e+05          7.500985e+06
# 75%             20.000000  9.715100e+05          1.090187e+07
# max             40.000000  1.107872e+06          2.616317e+08
#
#        NUmber_of_past_hospitalizations  Anual_Salary       charges
# count                      1338.000000  1.338000e+03   1338.000000
# mean                          1.060629  3.696849e+08  13270.422265
# std                           0.533184  5.656109e+08  12110.011237
# min                           0.000000  2.747072e+06   1121.873900
# 25%                           1.000000  7.755085e+07   4740.287150
# 50%                           1.000000  1.422756e+08   9382.033000
# 75%                           1.000000  3.298713e+08  16639.912515
# max                           3.000000  4.117197e+09  63770.428010

# %%
# to find the outlier
for col_name in col:
  if(insurance[col_name].dtypes=='int64' or insurance[col_name].dtypes=='float64'):
    plt.boxplot(insurance[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# #Upper fence = Q3 + 1.5 IQR   # value above which all values will become outliers
# #Lower fence = Q1 - 1.5 IQR   # valvue below which all values will become outliers
#
# #IQR = Q3 - Q1
# #Q3 = 75%
# #Q1 = 25%

# %%
Q1 = insurance.bmi.quantile(0.25)
Q3 = insurance.bmi.quantile(0.75)
IQR = Q3 - Q1
lf = Q1 - 1.5*IQR
uf = Q3 + 1.5*IQR
insurance = insurance[(insurance.bmi >= lf) & (insurance.bmi <= uf)]

Q1 = insurance.past_consultations.quantile(0.25)
Q3 = insurance.past_consultations.quantile(0.75)
IQR = Q3 - Q1
insurance = insurance[(insurance.past_consultations >= Q1 - 1.5*IQR) & (insurance.past_consultations <= Q3 + 1.5*IQR)]

Q1 = insurance.Hospital_expenditure.quantile(0.25)
Q3 = insurance.Hospital_expenditure.quantile(0.75)
IQR = Q3 - Q1
insurance = insurance[(insurance.Hospital_expenditure >= Q1 - 1.5*IQR) & (insurance.Hospital_expenditure <= Q3 + 1.5*IQR)]

Q1 = insurance.Anual_Salary.quantile(0.25)
Q3 = insurance.Anual_Salary.quantile(0.75)
IQR = Q3 - Q1
insurance = insurance[(insurance.Anual_Salary >= Q1 - 1.5*IQR) & (insurance.Anual_Salary <= Q3 + 1.5*IQR)]

# %%
for col_name in col:
  if(insurance[col_name].dtypes=='int64' or insurance[col_name].dtypes=='float64'):
    plt.boxplot(insurance[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()

# %%
insurance.corr(numeric_only = True)
# Out:
#                                       age       bmi  children  Claim_Amount  \
# age                              1.000000  0.155957  0.045371      0.117750
# bmi                              0.155957  1.000000  0.006477      0.008343
# children                         0.045371  0.006477  1.000000      0.041716
# Claim_Amount                     0.117750  0.008343  0.041716      1.000000
# past_consultations               0.172063  0.023543  0.045472      0.071569
# num_of_steps                     0.749468  0.040324  0.228830      0.185434
# Hospital_expenditure             0.160555  0.013992 -0.007494      0.054111
# NUmber_of_past_hospitalizations  0.519538  0.016121  0.316622      0.109748
# Anual_Salary                     0.490802  0.004105  0.064840      0.157826
# charges                          0.676071  0.010248  0.138470      0.192601
#
#                                  past_consultations  num_of_steps  \
# age                                        0.172063      0.749468
# bmi                                        0.023543      0.040324
# children                                   0.045472      0.228830
# Claim_Amount                               0.071569      0.185434
# past_consultations                         1.000000      0.259401
# num_of_steps                               0.259401      1.000000
# Hospital_expenditure                       0.088466      0.299554
# NUmber_of_past_hospitalizations            0.135498      0.714983
# Anual_Salary                               0.265710      0.767247
# charges                                    0.278131      0.936946
#
#                                  Hospital_expenditure  \
# age                                          0.160555
# bmi                                          0.013992
# children                                    -0.007494
# Claim_Amount                                 0.054111
# past_consultations                           0.088466
# num_of_steps                                 0.299554
# Hospital_expenditure                         1.000000
# NUmber_of_past_hospitalizations              0.129334
# Anual_Salary                                 0.366809
# charges                                      0.358378
#
#                                  NUmber_of_past_hospitalizations  \
# age                                                     0.519538
# bmi                                                     0.016121
# children                                                0.316622
# Claim_Amount                                            0.109748
# past_consultations                                      0.135498
# num_of_steps                                            0.714983
# Hospital_expenditure                                    0.129334
# NUmber_of_past_hospitalizations                         1.000000
# Anual_Salary                                            0.359422
# charges                                                 0.538116
#
#                                  Anual_Salary   charges
# age                                  0.490802  0.676071
# bmi                                  0.004105  0.010248
# children                             0.064840  0.138470
# Claim_Amount                         0.157826  0.192601
# past_consultations                   0.265710  0.278131
# num_of_steps                         0.767247  0.936946
# Hospital_expenditure                 0.366809  0.358378
# NUmber_of_past_hospitalizations      0.359422  0.538116
# Anual_Salary                         1.000000  0.892308
# charges                              0.892308  1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

col_list = []
for col in insurance.columns:
    if ((insurance[col].dtype != 'object') & (col != 'charges') ):
        col_list.append(col)

X = insurance[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                            feature        VIF
# 0                              age  15.452095
# 1                              bmi  26.330788
# 2                         children   2.029618
# 3                     Claim_Amount   5.678660
# 4               past_consultations   6.258017
# 5                     num_of_steps  61.574692
# 6             Hospital_expenditure   5.204376
# 7  NUmber_of_past_hospitalizations  12.052060
# 8                     Anual_Salary   5.481823

# %%
insurance = insurance.drop(['num_of_steps'],axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

col_list = []
for col in insurance.columns:
    if ((insurance[col].dtype != 'object') & (col != 'charges') ):
        col_list.append(col)

X = insurance[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                            feature        VIF
# 0                              age  14.484893
# 1                              bmi  12.261123
# 2                         children   2.017441
# 3                     Claim_Amount   5.243640
# 4               past_consultations   5.842169
# 5             Hospital_expenditure   4.929952
# 6  NUmber_of_past_hospitalizations  10.687768
# 7                     Anual_Salary   5.380679

# %%
insurance=insurance.drop(['age'], axis = 1)

# %%
col_list = []
for col in insurance.columns:
    if ((insurance[col].dtype != 'object') & (col != 'charges') ):
        col_list.append(col)

X = insurance[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                            feature        VIF
# 0                              bmi  10.323093
# 1                         children   1.978843
# 2                     Claim_Amount   5.228284
# 3               past_consultations   5.821933
# 4             Hospital_expenditure   4.929287
# 5  NUmber_of_past_hospitalizations   8.310570
# 6                     Anual_Salary   4.723495

# %%
insurance=insurance.drop(['bmi'], axis=1)

# %%
col_list = []
for col in insurance.columns:
    if ((insurance[col].dtype != 'object') & (col != 'charges') ):
        col_list.append(col)

X = insurance[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                            feature       VIF
# 0                         children  1.977037
# 1                     Claim_Amount  4.547332
# 2               past_consultations  5.049165
# 3             Hospital_expenditure  4.492630
# 4  NUmber_of_past_hospitalizations  7.245972
# 5                     Anual_Salary  4.688833

# %%
insurance=insurance.drop(['NUmber_of_past_hospitalizations'], axis=1)

# %%
col_list = []
for col in insurance.columns:
    if ((insurance[col].dtype != 'object') & (col != 'charges') ):
        col_list.append(col)

X = insurance[col_list]
\
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                 feature       VIF
# 0              children  1.713101
# 1          Claim_Amount  4.152224
# 2    past_consultations  4.670212
# 3  Hospital_expenditure  4.320876
# 4          Anual_Salary  4.279483

# %%
x=insurance.loc[:,['children','Claim_Amount','past_consultations','Hospital_expenditure','Anual_Salary']]
y=insurance.iloc[:,-1]  #This stores target column ie charges

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=50)

# %%
x.shape
# Out:
# (1030, 5)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (824, 5)
# (824,)
# (206, 5)
# (206,)

# %%
x_test
# Out:
#      children  Claim_Amount  past_consultations  Hospital_expenditure  \
# 502       1.0  16454.439830                 8.0          6.555520e+06
# 614       1.0  55007.636620                12.0          6.085390e+06
# 688       0.0  55041.113080                16.0          9.347759e+06
# 942       0.0  19528.415380                19.0          8.863814e+06
# 281       0.0   9560.754493                15.0          3.185350e+06
# ..        ...           ...                 ...                   ...
# 100       0.0  10894.889140                11.0          7.850745e+06
# 719       3.0  44544.860460                 9.0          1.010412e+07
# 801       1.0  22657.690130                15.0          5.841874e+06
# 486       3.0  47348.033700                10.0          6.034962e+06
# 494       1.0  27839.373370                13.0          8.119266e+06
#
#      Anual_Salary
# 502  6.103597e+07
# 614  1.606345e+08
# 688  1.776668e+08
# 942  2.244863e+08
# 281  7.490390e+07
# ..            ...
# 100  8.140885e+06
# 719  1.451976e+08
# 801  2.154320e+08
# 486  5.093163e+07
# 494  1.429523e+08
#
# [206 rows x 5 columns]

# %%
y_test
# Out:
# 502     7045.49900
# 614     8551.34700
# 688     9634.53800
# 942    13887.20400
# 281     4185.09790
#           ...
# 100     2104.11340
# 719    10115.00885
# 801    11394.06555
# 486     6753.03800
# 494     6858.47960
# Name: charges, Length: 206, dtype: float64

# %%
#buliding the model
l_model = LinearRegression()

# %%
l_model.fit(x_train, y_train) # training of the data
# Out:
# LinearRegression()

# %%
predictions = l_model.predict(x_test)
predictions
# Out:
# array([ 4233.90809023,  9588.38227966, 10374.06936822, 12192.88896501,
#         4597.20815512,  3127.69411913,  7312.15410521,  1070.8681189 ,
#         5277.40254077,  4394.60086778,  7016.93046779, 14660.74368902,
#         6324.19065154,  4485.12966152, 10118.578301  , 11192.3224461 ,
#         7826.49145697,  7816.63373704,  5041.66853676,  9677.01382356,
#         4622.09510602, 10670.11518535,  5688.79253381, 16493.82828511,
#         6276.25748951,  1762.7371427 ,  5970.04693584,  5307.48010525,
#         7421.25352849, 10414.86385208,  9807.28060928,  9187.20548359,
#         9484.64199165,  4218.51792106, 19254.2542141 , 16156.19878967,
#         6326.07936202,  8060.44208547,  4082.6962005 ,  3703.06373746,
#         3572.41548047, 11999.1213378 ,  6080.07517066,  8191.26930155,
#        10519.28155213,  6770.12772292,  6894.30702973, 12237.69923804,
#         4767.52034841, 18443.0632978 ,  7313.84797362, 12533.69386329,
#        12607.2531076 ,  5066.60127454,  4364.94824097,  3072.19954283,
#        10756.44820501,  4961.39246646,  4387.61714575,  9201.67207903,
#         7279.69853438,  4809.82339269,  7118.19071463,  4659.92500093,
#         9169.4227869 ,  3232.25896683,  7304.61448344,  5912.15310496,
#         7306.63212599,  5650.36307723,  8593.54203892, 12385.36262326,
#         7701.87032382,  7464.80787164,  9826.99474527,  6804.47442835,
#        13683.38152062,  9875.39315377,  8102.90581733,  5059.94445931,
#         4228.66877724,  9995.40483698, 12532.69768608,  3045.43583637,
#        16657.01854273,  3530.84678239,  6833.16169422,  4380.24189013,
#         3475.52929824,  6745.29601431, 16234.65880302,  5675.52399017,
#         5676.40679828, 11387.8073068 ,  7092.53540149,  4401.24964271,
#         7114.90446682,  6138.02526431,  5765.14950848,  4873.16082153,
#        15615.28247946,  6341.49808808,  4752.50952379,  8565.20376027,
#         8090.63652611, 10110.29272893,  4681.0593161 ,  8617.16804334,
#         7203.74496696, 10967.95731545,  5158.27915054,  4839.42051127,
#        10921.54746269,  8612.72836331, 10202.94565177, 12680.99650873,
#        16265.63372561,  7572.62109342, 10990.60240576,  4033.23063953,
#         2766.96054372,  4338.86996539,  7601.98984841, 18206.46233339,
#        13509.80092567,  9288.81903605, 10045.69915124, 10142.13225731,
#         4290.36155726,  5155.9077426 ,  9317.03223238,  5713.62695346,
#         4661.51434147,  8539.03894478, 21157.4701254 , 16567.51581984,
#         7382.46074966, 14242.05171733,  4716.40194087,  9882.49702648,
#         4534.51146658, 10644.13716306,  7499.98922804, 12932.95506433,
#         8208.10075053, 11037.16174017,  8799.6981714 ,  6497.23645335,
#        12599.22900945,  6007.5353798 ,  2640.03260603,  4197.71081509,
#        19061.7678444 ,  4568.96980801,  4109.2678272 ,  5784.71573841,
#        18884.64045404,  3064.76673475,  2375.67856764,  5608.43252257,
#         6223.51931634, 10443.04311042, 17369.71909028,  4627.35799586,
#         3085.60820233,  3835.29127214,  7670.84440077, 10518.56698569,
#         7313.743074  ,  5924.10312141,  4734.90984142,  9695.37293047,
#         6988.89146758,  3211.69767706, 10675.88647658, 10588.47826807,
#         5203.02184016,  2487.07962944,  3434.68004163,  4851.97064406,
#         6026.52255023, 15745.5760952 , 12344.25573558, 10522.32942016,
#         5473.80717989,  5172.62910732,  2872.35009487,  3099.16000876,
#         7408.48061863,  5210.81338353,  7768.47661285,  6621.68413955,
#        12500.47256851,  5254.80226414,  6743.07522866, 19450.80723365,
#         9572.6969074 ,  8150.90583626, 11869.06474234,  4448.31204176,
#         4371.92681723,  1502.42157319,  9282.09841448, 11840.04065646,
#         4680.2374976 ,  8480.1618902 ])

# %%
error_pred = pd.DataFrame(columns=['Actual_data','Prediction_data'])
error_pred
# Out:
# Empty DataFrame
# Columns: [Actual_data, Prediction_data]
# Index: []

# %%
error_pred['Actual_data']=y_test
error_pred
# Out:
#      Actual_data Prediction_data
# 502   7045.49900             NaN
# 614   8551.34700             NaN
# 688   9634.53800             NaN
# 942  13887.20400             NaN
# 281   4185.09790             NaN
# ..           ...             ...
# 100   2104.11340             NaN
# 719  10115.00885             NaN
# 801  11394.06555             NaN
# 486   6753.03800             NaN
# 494   6858.47960             NaN
#
# [206 rows x 2 columns]

# %%
error_pred['Prediction_data']=predictions
error_pred.head()
# Out:
#      Actual_data  Prediction_data
# 502    7045.4990      4233.908090
# 614    8551.3470      9588.382280
# 688    9634.5380     10374.069368
# 942   13887.2040     12192.888965
# 281    4185.0979      4597.208155

# %%
error_pred['Error']=error_pred['Actual_data']-error_pred['Prediction_data']

# %%
error_pred
# Out:
#      Actual_data  Prediction_data        Error
# 502   7045.49900      4233.908090  2811.590910
# 614   8551.34700      9588.382280 -1037.035280
# 688   9634.53800     10374.069368  -739.531368
# 942  13887.20400     12192.888965  1694.315035
# 281   4185.09790      4597.208155  -412.110255
# ..           ...              ...          ...
# 100   2104.11340      1502.421573   601.691827
# 719  10115.00885      9282.098414   832.910436
# 801  11394.06555     11840.040656  -445.975106
# 486   6753.03800      4680.237498  2072.800502
# 494   6858.47960      8480.161890 -1621.682290
#
# [206 rows x 3 columns]

# %%
# yi is actual value
# y^ is predicted value

# %%
from sklearn.metrics import *

# %%
r2_on_test = r2_score(y_test,predictions)
r2_on_test
# Out:
# 0.6424574409122072

# %%
rmse_on_test = mean_squared_error(y_test, predictions, squared=False)
rmse_on_test
# Out:
# 2523.97174427

# %%
mse_on_test = mean_squared_error(y_test, predictions, squared= True)
mse_on_test
# Out:
# 6370433.365873345

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mape_on_test= mean_absolute_percentage_error(y_test, predictions)
mape_on_test
# Out:
# 0.4897354899730046

# %%
plt.scatter(y_test,predictions)

# %%
import seaborn as sns
sns.regplot(x=y_test,y=predictions,ci=None,color='red')
# Out:
# <Axes: xlabel='charges'>

# %%
# Get the slope (coefficients) and intercept
slope = l_model.coef_
intercept = l_model.intercept_

print("Slope:", slope)
print("Intercept:", intercept)
# Out:
# Slope: [2.45490287e+02 1.33217239e-02 2.33689645e+01 3.75152495e-05
#  4.78424629e-05]
# Intercept: 416.22162073015625
